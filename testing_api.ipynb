# %%
import requests
import json

# %%
URL = "http://127.0.0.1:5000/predict"

data = {'asset_1': 'AMZN', 'asset_2': 'AAPL','asset_3' : 'nvda','asset_4': 'GOOG'}

teste = requests.post(URL, data=data )

# data = json.dumps({"test": ""})
# teste = requests.post(URL)

teste._content
# Out:
# b'\n<!DOCTYPE html>\n<html lang="en">\n<head>\n    <meta charset="UTF-8">\n    <title> Predicted  - by R.Lopes </title>\n    <link rel= "stylesheet" type= "text/css" href= "/static/styles/mainpage.css">\n    <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha1/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-GLhlTQ8iRABdZLl6O3oVMWSktQOp6b7In1Zl3/Jr59b6EGGoI1aFkw7cmDA6j6gD" crossorigin="anonymous">\n\t<script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha1/dist/js/bootstrap.bundle.min.js" integrity="sha384-w76AqPfDkMBDXo30jS1Sgez6pr3x5MlQ1ZAGC+nuZB+EYdgRZgiwxhTBTkF7CXvN" crossorigin="anonymous"></script>\n</head>\n\n<body>\n    <nav class=\'navbar \'>\n        <div class=\'container-fluid\'> \n            <a class=\'navbar-brand\' href=/>Markowitz App</a>\n            <a class=\'nav-link\' href=/about>About</a>\n        </div>\n    </nav>\n    <hr class=\'hr mt-0\'> \n \n\n    <div class="content">\n        \n<div class=\'container text-center\'>\n \n\n<div class=\'row\'> \n    <div class=\'col\' align=\'right\'> max sharpe ratio<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Max_Sharpe</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Return</th>\n      <td>0.328139</td>\n    </tr>\n    <tr>\n      <th>Volatility</th>\n      <td>0.293310</td>\n    </tr>\n    <tr>\n      <th>Sharpe</th>\n      <td>1.118743</td>\n    </tr>\n    <tr>\n      <th>AAPL</th>\n      <td>0.359954</td>\n    </tr>\n    <tr>\n      <th>AMZN</th>\n      <td>0.229756</td>\n    </tr>\n    <tr>\n      <th>GOOG</th>\n      <td>0.014622</td>\n    </tr>\n    <tr>\n      <th>NVDA</th>\n      <td>0.395668</td>\n    </tr>\n  </tbody>\n</table></div>\n    <div class=\'col\' align=\'left\'>  min volatility<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Min_vol</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Return</th>\n      <td>0.223019</td>\n    </tr>\n    <tr>\n      <th>Volatility</th>\n      <td>0.242035</td>\n    </tr>\n    <tr>\n      <th>Sharpe</th>\n      <td>0.797484</td>\n    </tr>\n    <tr>\n      <th>AAPL</th>\n      <td>0.358400</td>\n    </tr>\n    <tr>\n      <th>AMZN</th>\n      <td>0.154100</td>\n    </tr>\n    <tr>\n      <th>GOOG</th>\n      <td>0.487600</td>\n    </tr>\n    <tr>\n      <th>NVDA</th>\n      <td>0.000000</td>\n    </tr>\n  </tbody>\n</table> </div>\n</div>\n\n\n<div class=\'row\'>\n    <div class=\'col\' align=\'center\'>\n    <div id=\'chart\' class=\'chart\'\xe2\x80\x9d align=\'center\'></div>\n        <script src=\'https://cdn.plot.ly/plotly-latest.min.js\'></script>\n        <script type=\'text/javascript\'>\n        var graphs = {"data": [{"hovertemplate": "<i>Return</i>: %{y:.3f}<br>Volatility: %{x:.3f}<br>Sharpe: %{text:.3f}", "marker": {"color": [0.6532601154150648, 0.8963380284559012, 0.8899886004941422, 0.9833369407097642, 0.8500761438849109, 0.9671681606177288, 0.8762202963534392, 1.0129203343377036, 0.9976804561499794, 1.005268616964184, 0.9743020238407446, 0.9613807358605925, 0.9841789683580098, 0.9826788831723272, 1.0069967359438428, 0.8379881963563144, 0.8522950612433268, 1.0006567267597688, 0.8627515587636112, 0.9965503466865241, 0.878073723662866, 0.8301935990985441, 0.9671146531204756, 0.8498254155173726, 0.9555691500400516, 0.9543725709054585, 0.900455774313056, 0.9063087736205372, 0.8721660323965416, 0.9571139632086628, 0.946496919236058, 0.9310046553337241, 0.9809842652686236, 0.9241627568343932, 0.9877150830931882, 1.000527562668409, 0.8196422957310063, 0.9882490363266164, 0.9682576734932459, 0.9116241886827037, 0.9037097330213945, 0.914779047989272, 0.9651619008237473, 0.964917989529296, 0.8125765691561957, 0.9156407527829443, 0.9371679634986082, 0.9389679627128721, 0.8366931353142266, 0.9365150571837324, 0.9019245652562239, 0.9419317464492398, 0.9057958626978007, 0.9867394630003109, 0.9847679658452719, 0.8892323446157555, 0. ...

# %%
URL = "http://127.0.0.1:5000/"

data = json.dumps({'script_file': 'building_efficient_frontier.py'})
print(data)
# Send the POST request to the application with the data 
response = requests.post(URL, data=data) 
print(response)
 # Parse the response as JSON and print it out 
response_json = json.loads(response.headers) 
print(response_json)
# Out:
# {"script_file": "building_efficient_frontier.py"}
# <Response [405]>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\rafae\spyder files\Markowitz_Deploy\testing_api.ipynb Célula 3 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/rafae/spyder%20files/Markowitz_Deploy/testing_api.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> print(response)
#       <a href='vscode-notebook-cell:/c%3A/Users/rafae/spyder%20files/Markowitz_Deploy/testing_api.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>  # Parse the response as JSON and print it out
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rafae/spyder%20files/Markowitz_Deploy/testing_api.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> response_json = json.loads(response.headers)
#      <a href='vscode-notebook-cell:/c%3A/Users/rafae/spyder%20files/Markowitz_Deploy/testing_api.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> print(response_json)
#
# File c:\Program Files\Python38\lib\json\__init__.py:341, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339 else:
#     340     if not isinstance(s, (bytes, bytearray)):
# --> 341         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                         f'not {s.__class__.__name__}')
#     343     s = s.decode(detect_encoding(s), 'surrogatepass')
#     345 if "encoding" in kw:
#
# TypeError: the JSON object must be str, bytes or bytearray, not CaseInsensitiveDict
